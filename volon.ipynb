# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from dateutil import parser
from elasticsearch import Elasticsearch

# %%
# config
BASEURL = 'https://forum.vbulletin.com/forum/vbulletin-5-connect/vbulletin-5-suggestions'
MAXPAGE = 20
PAGINATION = False

# ElasticSearch
HOST = 'localhost'
PORT = 9200
INDEX = 'vbulletin'
DOCTYPE = 'post'

# %%
# get page URL from pagination
def getPageUrlFromPagination():
    soup = BeautifulSoup(requests.get(BASEURL).text, 'html.parser')
    arrUrl = {}
    for a in soup.find_all('a', href=True , attrs={'class':'js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--primary page js-pagenav-current-button js-pagenav-first-button'}):
        page = int(a.text)
        arrUrl[page] = (a['href'])
    for a in soup.find_all('a', href=True , attrs={'class':'js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary'}):
        page = int(a.text)
        arrUrl[page] = (a['href'])
    return arrUrl

# get page URL from page pattern
def getPageUrlFromPattern(baseUrl, maxPage):
    arrUrl = {}
    arrUrl[1] = baseUrl
    for i in range(2,maxPage):
        arrUrl[i] = f'{baseUrl}/page{i}'
    return arrUrl

# %%
# utility library
def formatDate(strDate):
    dt = parser.parse(strDate)
    return dt.isoformat()

# %%
# parsing Library
def getSubject(tr):
    return tr.find('a', attrs={'class':'topic-title js-topic-title'}).text
def getAuthor(tr):
    return tr.find('div', attrs={'class':'topic-info h-clear h-hide-on-small h-hide-on-narrow-column'}).find('a').text
def getCreatedAt(tr):
    isoCreatedAt = None
    layer = tr.find('div', attrs={'class':'topic-info h-clear h-hide-on-small h-hide-on-narrow-column'})
    if layer:
        strCreatedAt = layer.find('span', attrs={'class':'date'}).text
        isoCreatedAt = formatDate(strCreatedAt)
    return isoCreatedAt
def getResponses(tr):
    intResponse = 0
    strResponses = tr.find('div', attrs={'class':'posts-count'})
    if strResponses:
        strResponses = strResponses.text
        arrResponses = strResponses.split(' ')
        intResponse = int(arrResponses[0].replace(",", ""))
    return intResponse
def getViews(tr):
    intViews = 0
    strViews = tr.find('div', attrs={'class':'views-count'})
    if strViews:
        strViews = strViews.text
        arrViews = strViews.split(' ')
        intViews = int(arrViews[0].replace(",", ""))
    return intViews 
def getLastPostBy(tr):
    strLastPostBy = ''
    cellLastpost = tr.find('td', attrs={'class':'cell-lastpost'})
    if cellLastpost:
        divLastpost=cellLastpost.find('div', attrs={'class':'lastpost-by'})
        if divLastpost:
            strLastPostBy = divLastpost.find('a')
            if strLastPostBy:
                strLastPostBy = strLastPostBy.text
    return strLastPostBy
def getLastPostTime(tr):
    isoLastPostTime = None
    cellLastpost = tr.find('td', attrs={'class':'cell-lastpost'})
    if cellLastpost:
        strLastPostTime = cellLastpost.find('span', attrs={'class':'post-date'})
        if strLastPostTime:
            strLastPostTime = strLastPostTime.text
            isoLastPostTime = formatDate(strLastPostTime)
    return isoLastPostTime

# %%
# iterate over page
if PAGINATION:
    arrPage = getPageUrlFromPagination()
else:
    arrPage = getPageUrlFromPattern(BASEURL, MAXPAGE)
# 
connES=Elasticsearch([{'host':HOST,'port':PORT}])
# connES.indices.delete(index=INDEX)
for i in range(1,MAXPAGE):
    link = arrPage[i]
    objSoupHtml = BeautifulSoup(requests.get(link).text, 'html.parser')
    for tr in objSoupHtml.find_all('tr', attrs={'class':'topic-item'}):
        objPost = {}
        objPost['Post_subject'] = getSubject(tr)
        objPost['Author'] = getAuthor(tr)
        objPost['created_at'] = getCreatedAt(tr)
        objPost['responses'] = getResponses(tr)
        objPost['views_count'] = getViews(tr)
        objPost['last_post_by'] = getLastPostBy(tr)
        objPost['last_post_time'] = getLastPostTime(tr)
        connES.index(index=INDEX, doc_type=DOCTYPE, body=objPost)
print('Completed')
# Out:
# 1
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'vbulletin 5 marketplace', 'Author': 'ddkfoundations', 'created_at': '2019-06-20T10:20:00', 'responses': 2, 'views_count': 49, 'last_post_by': 'zweeper', 'last_post_time': '2019-06-20T22:23:00'}
# {'Post_subject': 'Signing into the VBulletin forums with username OR email', 'Author': 'kbarg', 'created_at': '2019-05-21T15:54:00', 'responses': 3, 'views_count': 67, 'last_post_by': 'kbarg', 'last_post_time': '2019-05-27T19:33:00'}
# {'Post_subject': 'VB 5 Shoutbox', 'Author': 'riser4what', 'created_at': '2019-05-19T10:06:00', 'responses': 8, 'views_count': 77, 'last_post_by': 'voyger', 'last_post_time': '2019-05-23T12:56:00'}
# {'Post_subject': 'Pin the first topic post', 'Author': 'Dmitrij', 'created_at': '2019-02-13T02:11:00', 'responses': 6, 'views_count': 123, 'last_post_by': 'Wayne Luke', 'last_post_time': '2019-03-28T08:40:00'}
# {'Post_subject': 'How does one open a JIRA ( i  think you call it )', 'Author': 'x.its.tongue.MOM', 'created_at': '2019-03-18T07:20:00', 'responses': 4, 'views_count': 132, 'last_post_by': 'x.its.tongue.MOM', 'last_post_time': '2019-03-18T15:28:00'}
# {'Post_subject': 'To quote a comment', 'Author': 'medved', 'created_at': '2019-01-21T11:45:00', 'responses': 13, 'views_count': 122, 'last_post_by': 'medved', 'last_post_time': '2019-01-22T16:39:00'}
# {'Post_subject': 'Improve the UI and the UX of the Channel Manager and the Channel Permissions in the AdminCP.', 'Author': 'hanm13', 'created_at': '2019-01-03T23:12:00', 'responses': 1, 'views_count': 401, 'last_post_by': 'Wayne Luke', 'last_post_time': '2019-01-08T13:15:00'}
# {'Post_subject': 'Better Reputation System', 'Author': 'Slowmin', 'created_at': '2018-12-02T14:40:00', 'responses': 5, 'views_count': 377, 'last_post_by': 'superj707', 'last_post_time': '2019-01-07T19:35:00'}
# {'Post_subject': 'Vb5 photo sluder', 'Author': 'moded', 'created_at': '2019-01-03T00:27:00', 'responses': 1, 'views_count': 205, 'last_post_by': 'Wayne Luke', 'last_post_time': '2019-01-03T08:49:00'}
# {'Post_subject': 'SQRL Implementation within vb', 'Author': 'Daryn', 'created_at': '2018-11-20T15:45:00', 'responses': 2, 'views_count': 234, 'last_post_by': 'Daryn', 'last_post_time': '2018-11-21T09:10:00'}
# {'Post_subject': 'A little professionalism', 'Author': 'domdom', 'created_at': '2018-10-24T21:54:00', 'responses': 0, 'views_count': 310, 'last_post_by': 'domdom', 'last_post_time': '2018-10-24T21:54:00'}
# {'Post_subject': 'OpenID', 'Author': 'icemanmx', 'created_at': '2018-10-13T20:07:00', 'responses': 1, 'views_count': 124, 'last_post_by': 'In Omnibus', 'last_post_time': '2018-10-13T20:49:00'}
# {'Post_subject': 'multi-langage', 'Author': 'domdom', 'created_at': '2018-10-12T17:47:00', 'responses': 0, 'views_count': 114, 'last_post_by': 'domdom', 'last_post_time': '2018-10-12T17:47:00'}
# {'Post_subject': 'Movie background', 'Author': 'icemanmx', 'created_at': '2018-10-11T16:50:00', 'responses': 1, 'views_count': 106, 'last_post_by': 'In Omnibus', 'last_post_time': '2018-10-11T17:06:00'}
# {'Post_subject': 'Need support for .svg extension', 'Author': 'icemanmx', 'created_at': '2018-10-08T08:56:00', 'responses': 2, 'views_count': 135, 'last_post_by': 'Wayne Luke', 'last_post_time': '2018-10-09T09:23:00'}
# {'Post_subject': 'Need badly Collapse the forums', 'Author': 'icemanmx', 'created_at': '2018-10-08T08:54:00', 'responses': 0, 'views_count': 34, 'last_post_by': 'icemanmx', 'last_post_time': '2018-10-08T08:54:00'}
# {'Post_subject': 'Disable post count per forum', 'Author': 'weltatlas', 'created_at': '2016-05-13T05:32:00', 'responses': 10, 'views_count': 389, 'last_post_by': 'delicjous', 'last_post_time': '2018-09-21T23:11:00'}
# {'Post_subject': 'Inline Moderation - Redirect', 'Author': 'In Omnibus', 'created_at': '2018-09-03T03:39:00', 'responses': 7, 'views_count': 103, 'last_post_by': 'In Omnibus', 'last_post_time': '2018-09-17T17:53:00'}
# {'Post_subject': 'Audio/Video attachments do not load and play on iOS devices', 'Author': 'Glenn Vergara', 'created_at': '2018-08-24T12:02:00', 'responses': 3, 'views_count': 88, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2018-08-30T08:28:00'}
# {'Post_subject': 'Banned user and privacy', 'Author': 'Mygra', 'created_at': '2018-07-27T06:52:00', 'responses': 6, 'views_count': 168, 'last_post_by': 'MrsTiggywinkle', 'last_post_time': '2018-07-28T09:14:00'}
# 2
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Upload and Stream Video', 'Author': 'Frank Davis', 'created_at': '2018-07-05T04:19:00', 'responses': 1, 'views_count': 143, 'last_post_by': 'In Omnibus', 'last_post_time': '2018-07-05T07:37:00'}
# {'Post_subject': 'Attachments as Post Icon', 'Author': 'Frank Davis', 'created_at': '2018-07-05T04:17:00', 'responses': 0, 'views_count': 37, 'last_post_by': 'Frank Davis', 'last_post_time': '2018-07-05T04:17:00'}
# {'Post_subject': 'when are we going to be able to have multi currency selection in the subscription api ?', 'Author': 'Anton Rahman', 'created_at': '2018-06-15T20:01:00', 'responses': 1, 'views_count': 75, 'last_post_by': 'Trevor Hannant', 'last_post_time': '2018-06-21T22:58:00'}
# {'Post_subject': 'Wordpress has many temples, whether vbulletin have some temples?', 'Author': 'Kevin Hu', 'created_at': '2018-06-11T16:03:00', 'responses': 3, 'views_count': 83, 'last_post_by': 'In Omnibus', 'last_post_time': '2018-06-11T19:00:00'}
# {'Post_subject': 'Agree checkbox for TOS and Privacy Policy', 'Author': 'JimMM', 'created_at': '2018-05-05T09:40:00', 'responses': 0, 'views_count': 257, 'last_post_by': 'JimMM', 'last_post_time': '2018-05-05T09:40:00'}
# {'Post_subject': 'SEO Improvement Suggestions', 'Author': 'ABDUR7MAAN', 'created_at': '2018-05-04T02:24:00', 'responses': 5, 'views_count': 107, 'last_post_by': 'ABDUR7MAAN', 'last_post_time': '2018-05-04T10:23:00'}
# {'Post_subject': 'Hit "Like" to see content and more', 'Author': 'Actron', 'created_at': '2018-04-20T09:57:00', 'responses': 2, 'views_count': 115, 'last_post_by': 'Actron', 'last_post_time': '2018-04-20T12:10:00'}
# {'Post_subject': 'Display moderator in the forum', 'Author': 'Mygra', 'created_at': '2018-03-24T01:49:00', 'responses': 3, 'views_count': 157, 'last_post_by': 'delicjous', 'last_post_time': '2018-03-26T00:06:00'}
# {'Post_subject': 'Ifttt link', 'Author': 'Sylv1', 'created_at': '2018-03-19T07:21:00', 'responses': 7, 'views_count': 142, 'last_post_by': 'Sylv1', 'last_post_time': '2018-03-23T23:51:00'}
# {'Post_subject': "these are the features I'm waiting for, write those you're waiting for.", 'Author': 'saiff', 'created_at': '2018-03-03T09:59:00', 'responses': 13, 'views_count': 337, 'last_post_by': 'Mark.B', 'last_post_time': '2018-03-19T01:07:00'}
# {'Post_subject': 'Simultaneous registration and synchronization with WP<->VB', 'Author': 'excentryk', 'created_at': '2018-02-15T04:51:00', 'responses': 0, 'views_count': 55, 'last_post_by': 'excentryk', 'last_post_time': '2018-02-15T04:51:00'}
# {'Post_subject': 'JS notification slider', 'Author': 'hanm13', 'created_at': '2018-01-30T02:38:00', 'responses': 0, 'views_count': 201, 'last_post_by': 'hanm13', 'last_post_time': '2018-01-30T02:38:00'}
# {'Post_subject': 'Traducao Portugues do Brasil - VB 5', 'Author': 'Vicente Medeiros', 'created_at': '2013-03-18T15:27:00', 'responses': 6, 'views_count': 2662, 'last_post_by': 'leon.henriques', 'last_post_time': '2017-12-18T02:41:00'}
# {'Post_subject': 'Attachment Download Counter Bug - Votes to fix needed please', 'Author': 'BarkyJ', 'created_at': '2017-12-06T14:24:00', 'responses': 0, 'views_count': 84, 'last_post_by': 'BarkyJ', 'last_post_time': '2017-12-06T14:24:00'}
# {'Post_subject': 'make Events stay on List for 2 hour after event Start Time', 'Author': 'mna', 'created_at': '2017-11-30T10:43:00', 'responses': 1, 'views_count': 102, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2017-11-30T16:02:00'}
# {'Post_subject': 'URL Whitelist Permissions By Usergroup', 'Author': 'In Omnibus', 'created_at': '2017-11-17T04:48:00', 'responses': 1, 'views_count': 88, 'last_post_by': 'rhens', 'last_post_time': '2017-11-17T09:56:00'}
# {'Post_subject': 'Topic redirects', 'Author': 'chriske', 'created_at': '2017-11-13T05:37:00', 'responses': 0, 'views_count': 60, 'last_post_by': 'chriske', 'last_post_time': '2017-11-13T05:37:00'}
# {'Post_subject': 'Why are these features missing?', 'Author': 'ABDUR7MAAN', 'created_at': '2017-11-03T19:02:00', 'responses': 2, 'views_count': 193, 'last_post_by': 'delicjous', 'last_post_time': '2017-11-08T07:00:00'}
# {'Post_subject': 'Sign up, login via Google+ and Twitter?', 'Author': 'botia', 'created_at': '2017-10-14T05:56:00', 'responses': 3, 'views_count': 150, 'last_post_by': 'Wayne Luke', 'last_post_time': '2017-10-17T11:35:00'}
# {'Post_subject': 'An option to mention a usergroup with @', 'Author': 'hanm13', 'created_at': '2017-10-12T04:27:00', 'responses': 1, 'views_count': 130, 'last_post_by': 'Mark.B', 'last_post_time': '2017-10-12T04:48:00'}
# 3
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Add Multiple PHP Hooks for Posts', 'Author': 'Glenn Vergara', 'created_at': '2017-03-30T08:45:00', 'responses': 4, 'views_count': 221, 'last_post_by': 'Emad ELsayed', 'last_post_time': '2017-10-03T06:35:00'}
# {'Post_subject': 'Anti Spam settings, getting a lot of forum spam lately, suggestion for a spambot stopper reject fast robot bot regs', 'Author': 'MDawg', 'created_at': '2017-10-01T10:48:00', 'responses': 0, 'views_count': 221, 'last_post_by': 'MDawg', 'last_post_time': '2017-10-01T10:48:00'}
# {'Post_subject': 'Handwritten/drawn posts function', 'Author': 'Zelda-King', 'created_at': '2017-09-09T12:42:00', 'responses': 2, 'views_count': 86, 'last_post_by': 'Zelda-King', 'last_post_time': '2017-09-10T11:12:00'}
# {'Post_subject': 'Where to increase limit to upload attachments', 'Author': 'keegmen', 'created_at': '2017-08-03T11:43:00', 'responses': 2, 'views_count': 130, 'last_post_by': 'Wayne Luke', 'last_post_time': '2017-08-04T11:53:00'}
# {'Post_subject': 'Invisible recaptcha and vbulletin 5', 'Author': 'MDawg', 'created_at': '2017-07-14T09:37:00', 'responses': 1, 'views_count': 121, 'last_post_by': 'Wayne Luke', 'last_post_time': '2017-07-14T09:44:00'}
# {'Post_subject': 'vBulletin Dark/Night Mode', 'Author': 'hanm13', 'created_at': '2017-06-29T02:33:00', 'responses': 0, 'views_count': 258, 'last_post_by': 'hanm13', 'last_post_time': '2017-06-29T02:33:00'}
# {'Post_subject': 'Publishing Options For Threads And Polls', 'Author': 'In Omnibus', 'created_at': '2017-06-08T12:08:00', 'responses': 1, 'views_count': 92, 'last_post_by': 'Wayne Luke', 'last_post_time': '2017-06-09T12:16:00'}
# {'Post_subject': 'Have Facebook, Google and Twitter got it all wrong?', 'Author': 'jdj', 'created_at': '2014-10-10T08:50:00', 'responses': 64, 'views_count': 1713, 'last_post_by': 'Wayne Luke', 'last_post_time': '2017-04-04T12:09:00'}
# {'Post_subject': 'Show Latest Threads in Realtime', 'Author': 'William Thomas Jr', 'created_at': '2017-03-29T23:01:00', 'responses': 2, 'views_count': 84, 'last_post_by': 'Mark.B', 'last_post_time': '2017-03-30T01:31:00'}
# {'Post_subject': 'Official Single Sign On Module Needed', 'Author': 'daddybird292', 'created_at': '2017-03-23T03:20:00', 'responses': 0, 'views_count': 99, 'last_post_by': 'daddybird292', 'last_post_time': '2017-03-23T03:20:00'}
# {'Post_subject': 'Should launch Plugin-Store, attract more developers', 'Author': 'Skyyg Skyg', 'created_at': '2017-03-13T05:37:00', 'responses': 6, 'views_count': 149, 'last_post_by': 'chriske', 'last_post_time': '2017-03-22T17:02:00'}
# {'Post_subject': 'Advanced Registration - Choose User Group', 'Author': 'shining', 'created_at': '2017-03-17T02:21:00', 'responses': 1, 'views_count': 58, 'last_post_by': 'Mark.B', 'last_post_time': '2017-03-17T06:33:00'}
# {'Post_subject': 'Blind carbon copy (BCC) in private messages', 'Author': 'Ozymandyus', 'created_at': '2017-03-14T10:11:00', 'responses': 1, 'views_count': 82, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2017-03-14T19:52:00'}
# {'Post_subject': 'Post a list of your most important bugs / feature requests', 'Author': 'chriske', 'created_at': '2017-02-13T15:16:00', 'responses': 5, 'views_count': 152, 'last_post_by': 'Wayne Luke', 'last_post_time': '2017-03-03T11:56:00'}
# {'Post_subject': 'Night Mode for vBulletin like used at Twitter?', 'Author': 'webgeek247', 'created_at': '2017-02-07T05:24:00', 'responses': 10, 'views_count': 227, 'last_post_by': 'webgeek247', 'last_post_time': '2017-02-12T06:52:00'}
# {'Post_subject': 'Another thread on user reputations', 'Author': 'imahawki', 'created_at': '2017-02-09T06:18:00', 'responses': 3, 'views_count': 101, 'last_post_by': 'imahawki', 'last_post_time': '2017-02-09T07:07:00'}
# {'Post_subject': 'Auto Links for VB5 ?', 'Author': 'discoverxs3', 'created_at': '2013-12-20T05:36:00', 'responses': 5, 'views_count': 283, 'last_post_by': 'discoverxs3', 'last_post_time': '2017-02-08T11:03:00'}
# {'Post_subject': 'Explanation of the Jira roadmap', 'Author': 'chriske', 'created_at': '2017-02-01T13:42:00', 'responses': 0, 'views_count': 0, 'last_post_by': '', 'last_post_time': None}
# {'Post_subject': 'Way to hide links from Guest/Unregistered users', 'Author': 'gh.rohit', 'created_at': '2015-11-24T06:35:00', 'responses': 17, 'views_count': 1292, 'last_post_by': 'chriske', 'last_post_time': '2017-01-31T14:50:00'}
# {'Post_subject': 'Photo attachments are downloaded - should open in new window instead', 'Author': 'naszeaudio', 'created_at': '2016-10-08T03:47:00', 'responses': 10, 'views_count': 227, 'last_post_by': 'chriske', 'last_post_time': '2017-01-31T14:46:00'}
# 4
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Provide additional URL option selection : Add option to route by node.', 'Author': 'Merenguista', 'created_at': '2016-09-03T07:19:00', 'responses': 2, 'views_count': 158, 'last_post_by': 'chriske', 'last_post_time': '2017-01-31T14:43:00'}
# {'Post_subject': 'Dedicated login page for VB5', 'Author': 'PiotrGT1', 'created_at': '2014-12-31T01:32:00', 'responses': 12, 'views_count': 268, 'last_post_by': 'Frank Davis', 'last_post_time': '2017-01-30T15:01:00'}
# {'Post_subject': 'Comparison Website type Functionality', 'Author': 'webgeek247', 'created_at': '2017-01-28T03:08:00', 'responses': 1, 'views_count': 49, 'last_post_by': 'webgeek247', 'last_post_time': '2017-01-30T09:19:00'}
# {'Post_subject': 'Issue with URL not being SEO friendly', 'Author': 'webgeek247', 'created_at': '2016-12-29T13:15:00', 'responses': 4, 'views_count': 139, 'last_post_by': 'webgeek247', 'last_post_time': '2017-01-28T02:56:00'}
# {'Post_subject': 'Public Media Gallery Module', 'Author': 'Throwam', 'created_at': '2016-12-22T15:34:00', 'responses': 1, 'views_count': 187, 'last_post_by': 'IggyP', 'last_post_time': '2016-12-22T21:48:00'}
# {'Post_subject': 'More widget visibility options', 'Author': 'unixman', 'created_at': '2016-12-05T04:52:00', 'responses': 6, 'views_count': 102, 'last_post_by': 'unixman', 'last_post_time': '2016-12-08T05:52:00'}
# {'Post_subject': 'Custom Profile Field with AJAX Lookup', 'Author': 'unixman', 'created_at': '2016-12-02T05:52:00', 'responses': 0, 'views_count': 38, 'last_post_by': 'unixman', 'last_post_time': '2016-12-02T05:52:00'}
# {'Post_subject': 'login or sign up', 'Author': 'yv3013', 'created_at': '2016-11-02T23:40:00', 'responses': 3, 'views_count': 207, 'last_post_by': 'Mattwhf', 'last_post_time': '2016-11-05T14:30:00'}
# {'Post_subject': 'Option that users delete ALL their private messages with ease', 'Author': 'goxy63', 'created_at': '2016-10-30T07:08:00', 'responses': 4, 'views_count': 122, 'last_post_by': 'goxy63', 'last_post_time': '2016-10-31T00:10:00'}
# {'Post_subject': 'Members who have visited today', 'Author': 'goxy63', 'created_at': '2016-10-28T17:15:00', 'responses': 3, 'views_count': 72, 'last_post_by': 'goxy63', 'last_post_time': '2016-10-29T06:42:00'}
# {'Post_subject': 'vBulletin5 Project Tools', 'Author': 'In Omnibus', 'created_at': '2016-07-06T04:23:00', 'responses': 0, 'views_count': 120, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-07-06T04:23:00'}
# {'Post_subject': 'Display Announcements to specific usergroup', 'Author': 'Dovaleh', 'created_at': '2016-03-02T07:12:00', 'responses': 1, 'views_count': 185, 'last_post_by': 'HowToEvery', 'last_post_time': '2016-06-13T01:53:00'}
# {'Post_subject': 'Request :Advanced Forum Statistics on vbulletin 5', 'Author': 'franzes80', 'created_at': '2016-05-14T03:22:00', 'responses': 1, 'views_count': 254, 'last_post_by': 'Trevor Hannant', 'last_post_time': '2016-05-15T23:28:00'}
# {'Post_subject': "Email notifications don't pick up changes made to phrases in AdminCP", 'Author': 'Fhabio', 'created_at': '2016-01-28T17:13:00', 'responses': 2, 'views_count': 163, 'last_post_by': 'Mark.B', 'last_post_time': '2016-04-13T21:27:00'}
# {'Post_subject': 'force user to select avatar on register?', 'Author': 'gcombe74', 'created_at': '2016-03-25T07:26:00', 'responses': 4, 'views_count': 235, 'last_post_by': 'Taim', 'last_post_time': '2016-04-13T19:33:00'}
# {'Post_subject': 'Remove Flash of Unstyled Content (FOUC)', 'Author': 'Glenn Vergara', 'created_at': '2016-03-14T12:43:00', 'responses': 2, 'views_count': 163, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2016-03-14T13:48:00'}
# {'Post_subject': 'Would like a Comment section for each user in User Manager', 'Author': 'Mackey', 'created_at': '2016-03-04T14:47:00', 'responses': 3, 'views_count': 177, 'last_post_by': 'Mark.B', 'last_post_time': '2016-03-06T13:22:00'}
# {'Post_subject': 'An easier way to ignore user groups in channel permissions', 'Author': 'pmquist', 'created_at': '2016-02-19T01:06:00', 'responses': 1, 'views_count': 149, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2016-02-19T17:39:00'}
# {'Post_subject': 'We need threaded mode', 'Author': 'preshpets', 'created_at': '2016-02-07T16:51:00', 'responses': 0, 'views_count': 128, 'last_post_by': 'preshpets', 'last_post_time': '2016-02-07T16:51:00'}
# {'Post_subject': 'Facebook Post to Page... and forum incon/other thumbnails missing when post link to Facebook', 'Author': 'Fhabio', 'created_at': '2016-01-28T17:27:00', 'responses': 1, 'views_count': 135, 'last_post_by': 'fenderbob', 'last_post_time': '2016-01-28T19:03:00'}
# 5
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'More improvement on Flag Report screen', 'Author': 'Fhabio', 'created_at': '2016-01-28T17:07:00', 'responses': 0, 'views_count': 61, 'last_post_by': 'Fhabio', 'last_post_time': '2016-01-28T17:07:00'}
# {'Post_subject': 'Photo Watermark', 'Author': 'medved', 'created_at': '2015-12-27T17:40:00', 'responses': 2, 'views_count': 214, 'last_post_by': 'Mark.B', 'last_post_time': '2015-12-28T03:04:00'}
# {'Post_subject': "Facebook selects user's avatars for featured images", 'Author': 'fenderbob', 'created_at': '2015-12-08T16:08:00', 'responses': 3, 'views_count': 164, 'last_post_by': 'In Omnibus', 'last_post_time': '2015-12-09T18:02:00'}
# {'Post_subject': 'Please add news feed modules for other pages...', 'Author': 'JohnPBee', 'created_at': '2015-12-02T20:01:00', 'responses': 0, 'views_count': 119, 'last_post_by': 'JohnPBee', 'last_post_time': '2015-12-02T20:01:00'}
# {'Post_subject': 'Idea for something like a CONTENT GALLERY MODULE', 'Author': 'pacinofurioso', 'created_at': '2015-10-29T16:25:00', 'responses': 7, 'views_count': 227, 'last_post_by': 'pacinofurioso', 'last_post_time': '2015-12-01T16:41:00'}
# {'Post_subject': 'Adding a native chatbox should be interesting', 'Author': 'roiarthur', 'created_at': '2015-06-23T08:00:00', 'responses': 9, 'views_count': 354, 'last_post_by': 'Mark.B', 'last_post_time': '2015-12-01T10:05:00'}
# {'Post_subject': 'Private Message notification', 'Author': 'osras1', 'created_at': '2015-11-20T08:08:00', 'responses': 2, 'views_count': 110, 'last_post_by': 'Trevor Hannant', 'last_post_time': '2015-11-30T02:47:00'}
# {'Post_subject': 'Quick navigation between posts (Next - previous) via keyboard shortcut J K and L for like', 'Author': 'AliMadkour', 'created_at': '2015-11-19T05:01:00', 'responses': 0, 'views_count': 238, 'last_post_by': 'AliMadkour', 'last_post_time': '2015-11-19T05:01:00'}
# {'Post_subject': 'Please add font size adjustment without the need for mods', 'Author': 'JohnPBee', 'created_at': '2015-10-22T11:53:00', 'responses': 4, 'views_count': 144, 'last_post_by': 'JohnPBee', 'last_post_time': '2015-10-24T16:11:00'}
# {'Post_subject': 'Interactive Sticky Threads', 'Author': 'fenderbob', 'created_at': '2015-09-22T06:52:00', 'responses': 0, 'views_count': 133, 'last_post_by': 'fenderbob', 'last_post_time': '2015-09-22T06:52:00'}
# {'Post_subject': 'Topic List view looks too crowded in small devices', 'Author': 'Glenn Vergara', 'created_at': '2015-08-24T17:05:00', 'responses': 1, 'views_count': 200, 'last_post_by': 'napy8gen', 'last_post_time': '2015-08-26T07:22:00'}
# {'Post_subject': 'Top bar that follows you', 'Author': 'Malcolmjr414', 'created_at': '2015-07-24T15:28:00', 'responses': 2, 'views_count': 193, 'last_post_by': 'Malcolmjr414', 'last_post_time': '2015-07-24T20:53:00'}
# {'Post_subject': 'Tags are a great way to categorize posts BUT...', 'Author': 'fenderbob', 'created_at': '2015-07-21T11:35:00', 'responses': 0, 'views_count': 98, 'last_post_by': 'fenderbob', 'last_post_time': '2015-07-21T11:35:00'}
# {'Post_subject': 'Split Screen Option', 'Author': 'In Omnibus', 'created_at': '2015-07-07T12:51:00', 'responses': 5, 'views_count': 134, 'last_post_by': 'In Omnibus', 'last_post_time': '2015-07-12T07:34:00'}
# {'Post_subject': 'Page specific site builder modules', 'Author': 'rhens', 'created_at': '2015-07-04T22:57:00', 'responses': 5, 'views_count': 115, 'last_post_by': 'Wayne Luke', 'last_post_time': '2015-07-07T11:12:00'}
# {'Post_subject': 'Forum Category Spacing', 'Author': 'beastmode', 'created_at': '2015-06-29T17:59:00', 'responses': 1, 'views_count': 109, 'last_post_by': 'Dominic', 'last_post_time': '2015-06-29T21:34:00'}
# {'Post_subject': 'Vb for blind users', 'Author': 'dashdbn', 'created_at': '2015-06-23T07:46:00', 'responses': 2, 'views_count': 109, 'last_post_by': 'dashdbn', 'last_post_time': '2015-06-24T12:14:00'}
# {'Post_subject': 'Profile Feeds function like Twitter + VB 5.x redesign Feeback', 'Author': 'Miykichii', 'created_at': '2014-03-10T05:55:00', 'responses': 9, 'views_count': 708, 'last_post_by': 'fionix', 'last_post_time': '2015-05-27T11:47:00'}
# {'Post_subject': 'Promote Article to Homepage Option', 'Author': 'Brad Padgett', 'created_at': '2015-04-03T03:08:00', 'responses': 9, 'views_count': 284, 'last_post_by': 'Brad Padgett', 'last_post_time': '2015-05-05T13:27:00'}
# {'Post_subject': 'Unique Numerical ID assigned publicly for Guests, Unregistered/Not Logged In users', 'Author': 'fenderbob', 'created_at': '2015-04-29T15:47:00', 'responses': 0, 'views_count': 106, 'last_post_by': 'fenderbob', 'last_post_time': '2015-04-29T15:47:00'}
# 6
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Impersonation', 'Author': 'ep0ch', 'created_at': '2015-04-13T08:18:00', 'responses': 10, 'views_count': 225, 'last_post_by': 'ep0ch', 'last_post_time': '2015-04-17T05:25:00'}
# {'Post_subject': 'Global Forum Ads', 'Author': 'Malcolmjr414', 'created_at': '2015-04-01T05:05:00', 'responses': 7, 'views_count': 290, 'last_post_by': 'webmastersun', 'last_post_time': '2015-04-12T19:30:00'}
# {'Post_subject': 'Ahhh, my eyes! Tracking lines or alternating colors would be nice!!!', 'Author': 'djcaseanova', 'created_at': '2015-03-10T14:20:00', 'responses': 4, 'views_count': 146, 'last_post_by': 'Wayne Luke', 'last_post_time': '2015-04-05T11:36:00'}
# {'Post_subject': 'Embed mp3s into forum', 'Author': 'donnyaz', 'created_at': '2015-03-27T04:31:00', 'responses': 3, 'views_count': 105, 'last_post_by': 'Mark.B', 'last_post_time': '2015-04-02T03:20:00'}
# {'Post_subject': 'A couple suggestions', 'Author': 'BugOutGirl', 'created_at': '2015-03-12T08:44:00', 'responses': 1, 'views_count': 75, 'last_post_by': 'Dominic', 'last_post_time': '2015-03-19T04:30:00'}
# {'Post_subject': 'View latest posts', 'Author': 'online68', 'created_at': '2015-03-13T07:18:00', 'responses': 2, 'views_count': 227, 'last_post_by': 'Mark.B', 'last_post_time': '2015-03-14T12:08:00'}
# {'Post_subject': 'Will we ever be able to delete our own replacement variables?', 'Author': 'BugOutGirl', 'created_at': '2015-03-11T13:57:00', 'responses': 4, 'views_count': 83, 'last_post_by': 'BugOutGirl', 'last_post_time': '2015-03-11T14:46:00'}
# {'Post_subject': 'append page numbers to paginated subforum titles', 'Author': 'sowmya002', 'created_at': '2015-03-05T19:28:00', 'responses': 3, 'views_count': 106, 'last_post_by': 'TLMD', 'last_post_time': '2015-03-09T02:22:00'}
# {'Post_subject': 'Streamlining the permissions process', 'Author': 'markavatar', 'created_at': '2015-03-07T12:41:00', 'responses': 0, 'views_count': 55, 'last_post_by': 'markavatar', 'last_post_time': '2015-03-07T12:41:00'}
# {'Post_subject': 'why is the php hooks topic closed?', 'Author': 'mangoz', 'created_at': '2015-02-24T16:40:00', 'responses': 12, 'views_count': 319, 'last_post_by': 'CarpCharacin', 'last_post_time': '2015-03-04T18:26:00'}
# {'Post_subject': 'there should be an easy way to backup the whole forum', 'Author': 'AddabaZZ', 'created_at': '2015-02-08T12:37:00', 'responses': 3, 'views_count': 185, 'last_post_by': 'AddabaZZ', 'last_post_time': '2015-02-27T09:41:00'}
# {'Post_subject': 'Chat (instant messaging)', 'Author': 'DemOnstar', 'created_at': '2013-05-08T09:06:00', 'responses': 18, 'views_count': 1008, 'last_post_by': 'mangoz', 'last_post_time': '2015-02-25T07:46:00'}
# {'Post_subject': 'Autolinker', 'Author': 'Graham Walters', 'created_at': '2015-02-13T14:17:00', 'responses': 0, 'views_count': 89, 'last_post_by': 'Graham Walters', 'last_post_time': '2015-02-13T14:17:00'}
# {'Post_subject': 'PHP Hooks Back again', 'Author': 'alexchar', 'created_at': '2014-11-09T01:14:00', 'responses': 25, 'views_count': 665, 'last_post_by': 'Wayne Luke', 'last_post_time': '2015-02-10T16:00:00'}
# {'Post_subject': 'Convert all gallery items into regular attachment and vice-versa', 'Author': 'PiotrGT1', 'created_at': '2015-02-08T01:21:00', 'responses': 1, 'views_count': 65, 'last_post_by': 'TLMD', 'last_post_time': '2015-02-08T02:58:00'}
# {'Post_subject': 'Integrated Logo maker', 'Author': 'Farook Ahmed', 'created_at': '2015-02-04T01:12:00', 'responses': 5, 'views_count': 148, 'last_post_by': 'Farook Ahmed', 'last_post_time': '2015-02-05T07:35:00'}
# {'Post_subject': 'in the threads, grey area on the left with author description takes too much space.', 'Author': 'Sylv1', 'created_at': '2015-01-04T12:00:00', 'responses': 2, 'views_count': 78, 'last_post_by': 'Sylv1', 'last_post_time': '2015-02-04T13:13:00'}
# {'Post_subject': 'Make it so you do not have to edit the config.php file at installation', 'Author': 'CarpCharacin', 'created_at': '2015-01-18T20:45:00', 'responses': 4, 'views_count': 176, 'last_post_by': 'Wayne Luke', 'last_post_time': '2015-01-28T16:13:00'}
# {'Post_subject': 'Members profile feeds', 'Author': 'Miykichii', 'created_at': '2015-01-15T05:30:00', 'responses': 0, 'views_count': 74, 'last_post_by': 'Miykichii', 'last_post_time': '2015-01-15T05:30:00'}
# {'Post_subject': 'Changing/updating URL structure of forum categories/channels', 'Author': 'PiotrGT1', 'created_at': '2015-01-01T06:57:00', 'responses': 4, 'views_count': 121, 'last_post_by': 'PiotrGT1', 'last_post_time': '2015-01-13T09:47:00'}
# 7
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Click to view original image size in Gallery', 'Author': 'PiotrGT1', 'created_at': '2015-01-10T09:06:00', 'responses': 3, 'views_count': 225, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2015-01-12T08:24:00'}
# {'Post_subject': 'European Law - Cookie notification', 'Author': 'PiotrGT1', 'created_at': '2015-01-11T10:31:00', 'responses': 2, 'views_count': 382, 'last_post_by': 'Mark.B', 'last_post_time': '2015-01-11T12:43:00'}
# {'Post_subject': 'How to improve content slider', 'Author': 'Miykichii', 'created_at': '2015-01-05T04:25:00', 'responses': 0, 'views_count': 126, 'last_post_by': 'Miykichii', 'last_post_time': '2015-01-05T04:25:00'}
# {'Post_subject': 'Hosted solution with SSL', 'Author': 'KamranR', 'created_at': '2014-12-12T10:50:00', 'responses': 0, 'views_count': 86, 'last_post_by': 'KamranR', 'last_post_time': '2014-12-12T10:50:00'}
# {'Post_subject': 'force stock player of iPhone and android device to play our forum attachmet', 'Author': 'fariborz khan', 'created_at': '2014-11-10T11:12:00', 'responses': 1, 'views_count': 91, 'last_post_by': 'fariborz khan', 'last_post_time': '2014-11-11T14:16:00'}
# {'Post_subject': 'consider spatial discount for everyone who has 2 or 3 MOTM in Vbulletin.org', 'Author': 'fariborz khan', 'created_at': '2014-11-03T15:08:00', 'responses': 0, 'views_count': 64, 'last_post_by': 'fariborz khan', 'last_post_time': '2014-11-03T15:08:00'}
# {'Post_subject': 'Change default filter settings', 'Author': 'hornstar6969', 'created_at': '2013-02-02T11:42:00', 'responses': 4, 'views_count': 277, 'last_post_by': 'Mark.B', 'last_post_time': '2014-09-25T03:01:00'}
# {'Post_subject': 'Improve search', 'Author': 'vibethemes', 'created_at': '2014-09-12T04:40:00', 'responses': 2, 'views_count': 200, 'last_post_by': 'Zachery', 'last_post_time': '2014-09-13T05:27:00'}
# {'Post_subject': 'Submit quick reply via keyboard shortcut (Crt+Enter or Shift+Enter)', 'Author': 'AliMadkour', 'created_at': '2014-09-01T21:16:00', 'responses': 7, 'views_count': 307, 'last_post_by': 'AliMadkour', 'last_post_time': '2014-09-07T16:29:00'}
# {'Post_subject': 'Responsive Image & Video Resizer', 'Author': 'Miykichii', 'created_at': '2014-05-18T10:21:00', 'responses': 2, 'views_count': 174, 'last_post_by': 'Mark.B', 'last_post_time': '2014-09-02T07:59:00'}
# {'Post_subject': 'testing app', 'Author': 'voclain', 'created_at': '2014-08-09T19:09:00', 'responses': 1, 'views_count': 96, 'last_post_by': 'voclain', 'last_post_time': '2014-08-10T09:22:00'}
# {'Post_subject': 'Spinners, loading icons in pure css', 'Author': 'Miykichii', 'created_at': '2014-06-16T08:57:00', 'responses': 1, 'views_count': 175, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2014-06-19T11:22:00'}
# {'Post_subject': 'Updated AdminCP CSS', 'Author': 'Zachery', 'created_at': '2014-06-13T10:07:00', 'responses': 0, 'views_count': 103, 'last_post_by': 'Zachery', 'last_post_time': '2014-06-13T10:07:00'}
# {'Post_subject': 'Homepage Grid vs List mode', 'Author': 'Miykichii', 'created_at': '2014-06-10T14:09:00', 'responses': 1, 'views_count': 170, 'last_post_by': 'Wayne Luke', 'last_post_time': '2014-06-10T14:23:00'}
# {'Post_subject': 'Blogs & Articles Redesign [Grid] Vs. [List] mode', 'Author': 'Miykichii', 'created_at': '2014-05-18T10:36:00', 'responses': 4, 'views_count': 1248, 'last_post_by': 'TLMD', 'last_post_time': '2014-06-08T12:31:00'}
# {'Post_subject': 'vB5: Ideas about the floating bar (+suggestion)', 'Author': 'TLMD', 'created_at': '2013-08-06T02:20:00', 'responses': 24, 'views_count': 951, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2014-05-21T09:51:00'}
# {'Post_subject': 'Implementing Disqus as an alternative comment system for Articles & Blogs', 'Author': 'Miykichii', 'created_at': '2014-05-18T10:12:00', 'responses': 11, 'views_count': 650, 'last_post_by': 'Miykichii', 'last_post_time': '2014-05-21T04:35:00'}
# {'Post_subject': 'For Usergroup Require Moderation for Posts problem', 'Author': 'anwar513', 'created_at': '2014-05-20T21:08:00', 'responses': 0, 'views_count': 133, 'last_post_by': 'anwar513', 'last_post_time': '2014-05-20T21:08:00'}
# {'Post_subject': 'Header redesign + Search bar improvement', 'Author': 'Miykichii', 'created_at': '2014-05-18T10:20:00', 'responses': 0, 'views_count': 198, 'last_post_by': 'Miykichii', 'last_post_time': '2014-05-18T10:20:00'}
# {'Post_subject': 'Implementing proper live notification system', 'Author': 'Miykichii', 'created_at': '2014-05-18T10:18:00', 'responses': 0, 'views_count': 237, 'last_post_by': 'Miykichii', 'last_post_time': '2014-05-18T10:18:00'}
# 8
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': "Improving Member's list", 'Author': 'Miykichii', 'created_at': '2014-05-18T10:17:00', 'responses': 0, 'views_count': 120, 'last_post_by': 'Miykichii', 'last_post_time': '2014-05-18T10:17:00'}
# {'Post_subject': 'Profile Media Tab + Album Image Views Features', 'Author': 'Miykichii', 'created_at': '2014-05-18T10:14:00', 'responses': 0, 'views_count': 251, 'last_post_by': 'Miykichii', 'last_post_time': '2014-05-18T10:14:00'}
# {'Post_subject': "Vbulletin's Group Redesign", 'Author': 'Miykichii', 'created_at': '2014-03-29T08:08:00', 'responses': 12, 'views_count': 553, 'last_post_by': 'Miykichii', 'last_post_time': '2014-05-17T04:28:00'}
# {'Post_subject': 'Auto Merge / Prevent Double Posting By Usergroup', 'Author': 'rhens', 'created_at': '2014-03-24T04:44:00', 'responses': 0, 'views_count': 255, 'last_post_by': 'rhens', 'last_post_time': '2014-03-24T04:44:00'}
# {'Post_subject': 'Better Page Management and Templates', 'Author': 'Robert Crawford', 'created_at': '2014-03-23T23:07:00', 'responses': 0, 'views_count': 54, 'last_post_by': 'Robert Crawford', 'last_post_time': '2014-03-23T23:07:00'}
# {'Post_subject': 'user name on the profile page error', 'Author': 'TürkGürcü', 'created_at': '2014-03-17T09:34:00', 'responses': 2, 'views_count': 120, 'last_post_by': 'nextgen', 'last_post_time': '2014-03-17T16:31:00'}
# {'Post_subject': 'Module addition for extensive Forums', 'Author': 'kpetite', 'created_at': '2014-03-15T13:25:00', 'responses': 0, 'views_count': 71, 'last_post_by': 'kpetite', 'last_post_time': '2014-03-15T13:25:00'}
# {'Post_subject': "Drag 'n drop channels", 'Author': 'SirPereira', 'created_at': '2014-02-24T03:49:00', 'responses': 8, 'views_count': 148, 'last_post_by': 'SirPereira', 'last_post_time': '2014-03-03T07:34:00'}
# {'Post_subject': 'Breadcrumb', 'Author': 'DemOnstar', 'created_at': '2013-04-01T21:56:00', 'responses': 4, 'views_count': 89, 'last_post_by': 'TimNL', 'last_post_time': '2014-02-28T05:50:00'}
# {'Post_subject': 'Back to the top and breadcrumbs', 'Author': 'humpty', 'created_at': '2013-01-13T01:28:00', 'responses': 12, 'views_count': 117, 'last_post_by': 'TimNL', 'last_post_time': '2014-02-28T05:49:00'}
# {'Post_subject': 'This issue is not important to you?', 'Author': 'anwar513', 'created_at': '2014-02-14T08:20:00', 'responses': 5, 'views_count': 342, 'last_post_by': 'feldon23', 'last_post_time': '2014-02-27T04:07:00'}
# {'Post_subject': 'Page Management', 'Author': 'coolv1994', 'created_at': '2014-02-20T07:07:00', 'responses': 2, 'views_count': 123, 'last_post_by': 'Lynne', 'last_post_time': '2014-02-20T09:52:00'}
# {'Post_subject': "Don't hide the Last Post column on the Forum Directory when in Mobile view", 'Author': 'Glenn Vergara', 'created_at': '2014-02-17T14:34:00', 'responses': 0, 'views_count': 106, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2014-02-17T14:34:00'}
# {'Post_subject': 'Individual Help links not working outside of the help', 'Author': 'John8', 'created_at': '2014-01-20T01:19:00', 'responses': 4, 'views_count': 143, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2014-02-14T12:50:00'}
# {'Post_subject': 'Add AdminCP option to define Content-Security-Policy HTTP header to prevent XSS attacks', 'Author': 'Glenn Vergara', 'created_at': '2014-02-13T15:42:00', 'responses': 0, 'views_count': 206, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2014-02-13T15:42:00'}
# {'Post_subject': "Request for red alert number for notifications/PM's/requests to disappear without having to delete", 'Author': 'MrSquid', 'created_at': '2014-01-09T20:51:00', 'responses': 1, 'views_count': 133, 'last_post_by': 'TLMD', 'last_post_time': '2014-01-10T03:41:00'}
# {'Post_subject': 'SHA256 hash function', 'Author': 'Tzu-Theory', 'created_at': '2013-11-22T10:15:00', 'responses': 4, 'views_count': 389, 'last_post_by': 'Kevin Sours', 'last_post_time': '2013-12-20T16:42:00'}
# {'Post_subject': 'A suggestion', 'Author': 'Omeka', 'created_at': '2013-11-18T14:12:00', 'responses': 1, 'views_count': 171, 'last_post_by': 'Mark.B', 'last_post_time': '2013-11-18T14:17:00'}
# {'Post_subject': 'how to block google to index similar content - example members urls-', 'Author': 'JamalFree', 'created_at': '2013-11-02T03:49:00', 'responses': 6, 'views_count': 402, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2013-11-06T15:54:00'}
# {'Post_subject': 'Overhaul the Search Feature', 'Author': 'RoG Viper RV', 'created_at': '2013-09-02T19:32:00', 'responses': 5, 'views_count': 184, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-10-28T13:48:00'}
# 9
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Use BB Code in Channel Title Description', 'Author': 'NxtGenCowboy', 'created_at': '2013-10-17T17:09:00', 'responses': 1, 'views_count': 204, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-10-23T09:47:00'}
# {'Post_subject': 'VB5 front page 3 collums', 'Author': 'imanutter', 'created_at': '2013-10-16T09:20:00', 'responses': 1, 'views_count': 184, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-10-16T10:18:00'}
# {'Post_subject': 'make choice available for us CUT RSS --- VOTE PLEASE--', 'Author': 'JamalFree', 'created_at': '2013-10-15T02:51:00', 'responses': 2, 'views_count': 109, 'last_post_by': 'JamalFree', 'last_post_time': '2013-10-15T13:26:00'}
# {'Post_subject': 'Click on the prefix', 'Author': 'zel', 'created_at': '2013-10-09T06:31:00', 'responses': 6, 'views_count': 220, 'last_post_by': 'IcEWoLF', 'last_post_time': '2013-10-14T21:18:00'}
# {'Post_subject': 'we need some improvement like xenforo for show members', 'Author': 'JamalFree', 'created_at': '2013-10-12T13:33:00', 'responses': 3, 'views_count': 222, 'last_post_by': 'JamalFree', 'last_post_time': '2013-10-14T03:35:00'}
# {'Post_subject': 'Add "Answered" status to Topics', 'Author': 'z-at-ox', 'created_at': '2013-10-04T05:46:00', 'responses': 0, 'views_count': 128, 'last_post_by': 'z-at-ox', 'last_post_time': '2013-10-04T05:46:00'}
# {'Post_subject': 'Be able to add topic prefixes to multiples forums', 'Author': 'z-at-ox', 'created_at': '2013-09-30T11:56:00', 'responses': 2, 'views_count': 151, 'last_post_by': 'z-at-ox', 'last_post_time': '2013-09-30T12:53:00'}
# {'Post_subject': 'add line item "sticky/unstick threads to user permissions', 'Author': 'Huskermax', 'created_at': '2013-09-30T09:52:00', 'responses': 0, 'views_count': 84, 'last_post_by': 'Huskermax', 'last_post_time': '2013-09-30T09:52:00'}
# {'Post_subject': 'couple issues bothering me...', 'Author': 'IggyP', 'created_at': '2013-09-29T03:29:00', 'responses': 0, 'views_count': 94, 'last_post_by': 'IggyP', 'last_post_time': '2013-09-29T03:29:00'}
# {'Post_subject': 'Add visual cue or indication after scrolling down to an anchored post', 'Author': 'Glenn Vergara', 'created_at': '2013-09-25T09:52:00', 'responses': 0, 'views_count': 174, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2013-09-25T09:52:00'}
# {'Post_subject': 'Please add the a function [PRBREAK][/PRBREAK] in the blogs', 'Author': 'egerr', 'created_at': '2013-09-21T08:11:00', 'responses': 3, 'views_count': 123, 'last_post_by': 'egerr', 'last_post_time': '2013-09-21T08:50:00'}
# {'Post_subject': 'Give Users The Option to Not Use the Crap WYSIWYG "Site Breaker"', 'Author': 'CygnusFTK', 'created_at': '2013-09-17T18:28:00', 'responses': 0, 'views_count': 133, 'last_post_by': 'CygnusFTK', 'last_post_time': '2013-09-17T18:28:00'}
# {'Post_subject': 'Not a poll', 'Author': 'DemOnstar', 'created_at': '2013-09-10T09:03:00', 'responses': 6, 'views_count': 83, 'last_post_by': 'DemOnstar', 'last_post_time': '2013-09-11T11:36:00'}
# {'Post_subject': 'vBulletin 5 LDAP auth', 'Author': 'Halandar', 'created_at': '2013-09-10T06:59:00', 'responses': 0, 'views_count': 617, 'last_post_by': 'Halandar', 'last_post_time': '2013-09-10T06:59:00'}
# {'Post_subject': 'Member list: Improvements on design/usability and features', 'Author': 'TLMD', 'created_at': '2013-08-23T03:27:00', 'responses': 11, 'views_count': 1207, 'last_post_by': 'CheeseMan316', 'last_post_time': '2013-09-03T10:53:00'}
# {'Post_subject': 'Add an AdminCP option to allow the jQuery js file to be included in the <head>', 'Author': 'Glenn Vergara', 'created_at': '2013-08-29T16:30:00', 'responses': 0, 'views_count': 168, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2013-08-29T16:30:00'}
# {'Post_subject': 'Add hook before </body> tag fter all script includes', 'Author': 'Glenn Vergara', 'created_at': '2013-08-25T12:55:00', 'responses': 3, 'views_count': 268, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2013-08-26T08:50:00'}
# {'Post_subject': 'Hover Profile Preview', 'Author': 'Glenn Vergara', 'created_at': '2013-08-21T00:28:00', 'responses': 8, 'views_count': 344, 'last_post_by': 'tonmo', 'last_post_time': '2013-08-26T02:51:00'}
# {'Post_subject': 'A Way to Make the Header MUCH More Configurable?', 'Author': 'CygnusFTK', 'created_at': '2013-08-20T20:14:00', 'responses': 2, 'views_count': 84, 'last_post_by': 'TLMD', 'last_post_time': '2013-08-21T00:53:00'}
# {'Post_subject': 'Bring back the old school pagination.', 'Author': 'IcEWoLF', 'created_at': '2013-08-04T17:21:00', 'responses': 25, 'views_count': 263, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2013-08-19T12:10:00'}
# 10
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Deleting photos', 'Author': 'AmeliaJane1', 'created_at': '2013-08-18T01:53:00', 'responses': 0, 'views_count': 63, 'last_post_by': 'AmeliaJane1', 'last_post_time': '2013-08-18T01:53:00'}
# {'Post_subject': 'Allow quoting single passages within a post', 'Author': 'TLMD', 'created_at': '2013-08-03T04:51:00', 'responses': 8, 'views_count': 103, 'last_post_by': 'Glenn Vergara', 'last_post_time': '2013-08-16T14:51:00'}
# {'Post_subject': 'CMS Solution Idea', 'Author': 'interfx', 'created_at': '2013-08-15T13:03:00', 'responses': 1, 'views_count': 58, 'last_post_by': 'Mark.B', 'last_post_time': '2013-08-15T13:51:00'}
# {'Post_subject': 'Collapsed modules should remain in such state', 'Author': 'TLMD', 'created_at': '2013-08-09T10:22:00', 'responses': 1, 'views_count': 130, 'last_post_by': 'Mark.B', 'last_post_time': '2013-08-09T10:38:00'}
# {'Post_subject': 'Allow to show only support/staff members in the member list', 'Author': 'TLMD', 'created_at': '2013-08-09T09:47:00', 'responses': 3, 'views_count': 581, 'last_post_by': 'Mark.B', 'last_post_time': '2013-08-09T10:20:00'}
# {'Post_subject': 'Report a users profile', 'Author': 'Kent55', 'created_at': '2013-07-31T03:42:00', 'responses': 11, 'views_count': 58, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-08-08T10:10:00'}
# {'Post_subject': 'Attach an icon to topics, if a certain usergroup has posted in it', 'Author': 'TLMD', 'created_at': '2013-08-03T16:44:00', 'responses': 0, 'views_count': 129, 'last_post_by': 'TLMD', 'last_post_time': '2013-08-03T16:44:00'}
# {'Post_subject': 'Drag and drop forum permissions', 'Author': 'Kent55', 'created_at': '2013-08-01T08:26:00', 'responses': 0, 'views_count': 78, 'last_post_by': 'Kent55', 'last_post_time': '2013-08-01T08:26:00'}
# {'Post_subject': 'Scroll page to beginning of content list when opening a channel', 'Author': 'DemOnstar', 'created_at': '2013-05-10T06:29:00', 'responses': 4, 'views_count': 57, 'last_post_by': 'ovidiu', 'last_post_time': '2013-08-01T04:55:00'}
# {'Post_subject': 'Add advanced user info in posts + general design changes', 'Author': 'TLMD', 'created_at': '2013-07-11T00:58:00', 'responses': 1, 'views_count': 86, 'last_post_by': 'Kent55', 'last_post_time': '2013-07-30T14:41:00'}
# {'Post_subject': 'Set default options for reporting a post', 'Author': 'Kent55', 'created_at': '2013-07-30T14:27:00', 'responses': 0, 'views_count': 31, 'last_post_by': 'Kent55', 'last_post_time': '2013-07-30T14:27:00'}
# {'Post_subject': 'Usergroup/Staff Banners', 'Author': 'Kent55', 'created_at': '2013-07-30T11:54:00', 'responses': 4, 'views_count': 540, 'last_post_by': 'Kent55', 'last_post_time': '2013-07-30T13:49:00'}
# ...
# {'Post_subject': 'New features..', 'Author': 'DemOnstar', 'created_at': '2013-02-08T03:50:00', 'responses': 2, 'views_count': 44, 'last_post_by': 'DemOnstar', 'last_post_time': '2013-02-11T02:39:00'}
# {'Post_subject': 'improvement for the human verification option', 'Author': 'sukagwe', 'created_at': '2013-02-07T21:04:00', 'responses': 1, 'views_count': 66, 'last_post_by': 'Joe D.', 'last_post_time': '2013-02-09T03:51:00'}
# {'Post_subject': 'motion captcha to prevent spam', 'Author': 'sukagwe', 'created_at': '2013-01-31T19:22:00', 'responses': 10, 'views_count': 198, 'last_post_by': 'DemOnstar', 'last_post_time': '2013-02-08T04:30:00'}
# {'Post_subject': 'Guests Can Only See Thread Opener', 'Author': 'Mondy', 'created_at': '2013-01-30T18:29:00', 'responses': 1, 'views_count': 47, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-02-07T11:07:00'}
# {'Post_subject': 'Instant Notification By Email for forums', 'Author': 'hamids47', 'created_at': '2013-01-23T23:25:00', 'responses': 1, 'views_count': 44, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-01-29T08:35:00'}
# {'Post_subject': 'Videos in a lightbox', 'Author': 'humpty', 'created_at': '2013-01-29T01:03:00', 'responses': 0, 'views_count': 62, 'last_post_by': 'humpty', 'last_post_time': '2013-01-29T01:03:00'}
# {'Post_subject': 'Combine css files and Javascript files', 'Author': 'randomdriver', 'created_at': '2013-01-22T10:42:00', 'responses': 5, 'views_count': 523, 'last_post_by': 'brandondrury', 'last_post_time': '2013-01-28T09:52:00'}
# {'Post_subject': 'Notify user if quoted.', 'Author': 'DeltaHawk5', 'created_at': '2013-01-08T17:10:00', 'responses': 4, 'views_count': 71, 'last_post_by': 'DeltaHawk5', 'last_post_time': '2013-01-23T21:18:00'}
# {'Post_subject': 'Mentioning on VB5?', 'Author': 'Recep Baltaş', 'created_at': '2013-01-16T16:10:00', 'responses': 6, 'views_count': 69, 'last_post_by': 'hornstar6969', 'last_post_time': '2013-01-21T16:28:00'}
# {'Post_subject': 'create a new blog', 'Author': 'sukagwe', 'created_at': '2013-01-17T09:21:00', 'responses': 0, 'views_count': 38, 'last_post_by': 'sukagwe', 'last_post_time': '2013-01-17T09:21:00'}
# {'Post_subject': 'New Module suggestion', 'Author': 'WhiskeyOSS', 'created_at': '2013-01-13T04:13:00', 'responses': 2, 'views_count': 34, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-01-14T06:01:00'}
# {'Post_subject': 'Ability to reuse/save a module', 'Author': 'kyle1745', 'created_at': '2013-01-12T19:55:00', 'responses': 2, 'views_count': 55, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-01-14T05:59:00'}
# {'Post_subject': 'Styles & Color Style', 'Author': 'kyle1745', 'created_at': '2013-01-12T19:53:00', 'responses': 3, 'views_count': 56, 'last_post_by': 'Mark.B', 'last_post_time': '2013-01-13T11:07:00'}
# {'Post_subject': 'add users to another users ignore list in admin cp', 'Author': 'Huskermax', 'created_at': '2013-01-09T09:49:00', 'responses': 0, 'views_count': 73, 'last_post_by': 'Huskermax', 'last_post_time': '2013-01-09T09:49:00'}
# {'Post_subject': 'Display of Subcategories', 'Author': 'GrdPa', 'created_at': '2013-01-09T06:01:00', 'responses': 0, 'views_count': 71, 'last_post_by': 'GrdPa', 'last_post_time': '2013-01-09T06:01:00'}
# {'Post_subject': 'Reputation Numbers', 'Author': 'Grotesque', 'created_at': '2013-01-07T07:35:00', 'responses': 2, 'views_count': 46, 'last_post_by': 'Grotesque', 'last_post_time': '2013-01-07T14:24:00'}
# {'Post_subject': 'Built in report like google analytics', 'Author': 'Gripi', 'created_at': '2013-01-01T10:45:00', 'responses': 1, 'views_count': 48, 'last_post_by': 'Wayne Luke', 'last_post_time': '2013-01-01T10:48:00'}
# {'Post_subject': 'Add your votes for this.. "to many popups"', 'Author': 'Jntu Hub', 'created_at': '2012-12-28T08:23:00', 'responses': 0, 'views_count': 40, 'last_post_by': 'Jntu Hub', 'last_post_time': '2012-12-28T08:23:00'}
# {'Post_subject': 'Built in report notification', 'Author': 'Kent55', 'created_at': '2012-12-24T06:02:00', 'responses': 3, 'views_count': 77, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-12-25T14:00:00'}
# {'Post_subject': 'Final version', 'Author': 'nicutdk', 'created_at': '2012-12-23T07:32:00', 'responses': 2, 'views_count': 27, 'last_post_by': 'Aakif N.', 'last_post_time': '2012-12-23T08:06:00'}
# 14
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Add Number of Views', 'Author': 'albanah', 'created_at': '2012-12-21T09:59:00', 'responses': 2, 'views_count': 66, 'last_post_by': 'Mark.B', 'last_post_time': '2012-12-21T10:02:00'}
# {'Post_subject': 'Module Save', 'Author': 'WhiskeyOSS', 'created_at': '2012-12-18T14:25:00', 'responses': 2, 'views_count': 42, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-12-19T09:55:00'}
# {'Post_subject': 'Spam Bot Search Tool (SBST)', 'Author': 'GT500', 'created_at': '2012-11-29T01:01:00', 'responses': 4, 'views_count': 83, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-29T09:33:00'}
# {'Post_subject': 'jQuery Featured Slider', 'Author': 'DeltaHawk5', 'created_at': '2012-11-18T14:44:00', 'responses': 3, 'views_count': 237, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-23T12:01:00'}
# {'Post_subject': 'An update is really needed', 'Author': 'John Diver', 'created_at': '2012-11-16T06:32:00', 'responses': 1, 'views_count': 31, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-16T07:41:00'}
# {'Post_subject': 'Adding another search option to USERS/SEARCH FOR USERS', 'Author': 'Tim Hargrove', 'created_at': '2012-11-13T10:26:00', 'responses': 1, 'views_count': 40, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-13T10:37:00'}
# {'Post_subject': 'Hide Off Topic posts function', 'Author': 'Huskermax', 'created_at': '2012-11-13T07:58:00', 'responses': 1, 'views_count': 84, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-13T10:12:00'}
# {'Post_subject': 'Allow expiring timer for sticky threads', 'Author': 'Huskermax', 'created_at': '2012-11-13T07:55:00', 'responses': 0, 'views_count': 49, 'last_post_by': 'Huskermax', 'last_post_time': '2012-11-13T07:55:00'}
# {'Post_subject': "Allow auto infraction/warnings notifications to go to email and pm's", 'Author': 'Huskermax', 'created_at': '2012-11-09T09:24:00', 'responses': 6, 'views_count': 170, 'last_post_by': 'Huskermax', 'last_post_time': '2012-11-13T07:53:00'}
# {'Post_subject': 'Messy', 'Author': 'acwatts', 'created_at': '2012-10-06T00:01:00', 'responses': 3, 'views_count': 36, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-05T09:22:00'}
# {'Post_subject': 'Profile Option: Notification on quote.', 'Author': 'Devin Hutchison', 'created_at': '2012-11-03T11:37:00', 'responses': 2, 'views_count': 516, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-05T09:20:00'}
# {'Post_subject': 'See who liked a post', 'Author': 'alfanexus', 'created_at': '2012-10-10T02:44:00', 'responses': 8, 'views_count': 136, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-05T09:16:00'}
# {'Post_subject': 'make easy to Template / Mod installations', 'Author': 'Jntu Hub', 'created_at': '2012-11-05T09:00:00', 'responses': 1, 'views_count': 47, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-11-05T09:14:00'}
# {'Post_subject': 'Why no microdata?', 'Author': 'StarBuG', 'created_at': '2012-10-16T02:00:00', 'responses': 1, 'views_count': 160, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-10-16T09:33:00'}
# {'Post_subject': 'New Threads/Posts Posted to Twitter', 'Author': 'thenoob2012', 'created_at': '2012-09-18T05:36:00', 'responses': 11, 'views_count': 271, 'last_post_by': 'Hunter Kino', 'last_post_time': '2012-10-15T19:23:00'}
# {'Post_subject': 'Invite system', 'Author': 'E0N', 'created_at': '2012-09-14T01:04:00', 'responses': 4, 'views_count': 70, 'last_post_by': 'blueperspective', 'last_post_time': '2012-10-15T11:34:00'}
# {'Post_subject': 'Ability to Add Extra Thread Fields', 'Author': 'thenoob2012', 'created_at': '2012-10-12T21:29:00', 'responses': 1, 'views_count': 187, 'last_post_by': 'mathias', 'last_post_time': '2012-10-14T08:33:00'}
# {'Post_subject': 'Split the overview of content subscriptions and member subscriptions in two', 'Author': 'alfanexus', 'created_at': '2012-10-12T03:37:00', 'responses': 0, 'views_count': 54, 'last_post_by': 'alfanexus', 'last_post_time': '2012-10-12T03:37:00'}
# {'Post_subject': 'Words and buttons touching the edges of tables', 'Author': 'SKSApps', 'created_at': '2012-10-05T12:30:00', 'responses': 1, 'views_count': 42, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-10-06T07:29:00'}
# {'Post_subject': 'integration between vBulletin + facebook', 'Author': '3bir.com', 'created_at': '2012-09-28T10:22:00', 'responses': 1, 'views_count': 302, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-28T10:37:00'}
# 15
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'The clean way to upgrade', 'Author': 'Veniamin', 'created_at': '2012-09-28T10:32:00', 'responses': 1, 'views_count': 27, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-28T10:35:00'}
# {'Post_subject': 'Few suggestions', 'Author': 'Spit-wad', 'created_at': '2012-09-27T19:16:00', 'responses': 1, 'views_count': 27, 'last_post_by': 'Zachery', 'last_post_time': '2012-09-27T19:23:00'}
# {'Post_subject': 'Twitter/Google/OpenID for account creation and login?', 'Author': 'Sushubh', 'created_at': '2012-09-25T11:53:00', 'responses': 1, 'views_count': 920, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-25T14:14:00'}
# {'Post_subject': 'Support for embedded image uploader', 'Author': 'Sushubh', 'created_at': '2012-09-25T12:02:00', 'responses': 1, 'views_count': 76, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-25T14:13:00'}
# {'Post_subject': 'Back-Up Service', 'Author': 'DecNetPHase4', 'created_at': '2012-09-25T10:00:00', 'responses': 2, 'views_count': 40, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-25T14:12:00'}
# {'Post_subject': 'the look of vBulletin 5 is too simple', 'Author': 'sukagwe', 'created_at': '2012-09-24T05:55:00', 'responses': 11, 'views_count': 53, 'last_post_by': 'vijayninel', 'last_post_time': '2012-09-25T11:02:00'}
# {'Post_subject': 'vBulletin 5 and IPv6', 'Author': 'we_are_borg', 'created_at': '2012-09-11T07:01:00', 'responses': 37, 'views_count': 638, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-25T08:01:00'}
# {'Post_subject': 'Suggestion: Bridge for two (or more) vBulletin 5 Connect Sites', 'Author': 'jdj', 'created_at': '2012-09-25T00:54:00', 'responses': 1, 'views_count': 205, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-25T07:58:00'}
# {'Post_subject': 'vBulletin 5 for mobile application', 'Author': 'sukagwe', 'created_at': '2012-09-24T09:31:00', 'responses': 2, 'views_count': 67, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-25T06:04:00'}
# {'Post_subject': 'Image viewer - click image for full size needed.', 'Author': 'pokesph', 'created_at': '2012-09-24T09:53:00', 'responses': 1, 'views_count': 96, 'last_post_by': 'Zachery', 'last_post_time': '2012-09-24T09:58:00'}
# {'Post_subject': 'Please, consider this.', 'Author': 'sukagwe', 'created_at': '2012-09-24T06:12:00', 'responses': 2, 'views_count': 32, 'last_post_by': 'sukagwe', 'last_post_time': '2012-09-24T09:46:00'}
# {'Post_subject': 'the different usergroup between bot & guess(unregistered)', 'Author': 'sukagwe', 'created_at': '2012-09-20T22:56:00', 'responses': 5, 'views_count': 66, 'last_post_by': 'sukagwe', 'last_post_time': '2012-09-22T22:06:00'}
# {'Post_subject': 'Vote : for Integration of AntiSpam Registration', 'Author': 'simonhind', 'created_at': '2012-09-19T12:23:00', 'responses': 1, 'views_count': 42, 'last_post_by': 'Marco Mamdouh', 'last_post_time': '2012-09-19T17:34:00'}
# {'Post_subject': 'Comments View / Subscription', 'Author': 'lostincable', 'created_at': '2012-09-15T13:50:00', 'responses': 1, 'views_count': 32, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-16T14:19:00'}
# {'Post_subject': 'vbulletin 5 Blog layout suggestions', 'Author': 'asprens', 'created_at': '2012-09-12T05:06:00', 'responses': 1, 'views_count': 92, 'last_post_by': 'Alfa1', 'last_post_time': '2012-09-15T05:29:00'}
# {'Post_subject': 'columns', 'Author': 'atcspaul', 'created_at': '2012-09-13T03:43:00', 'responses': 1, 'views_count': 34, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-14T21:38:00'}
# {'Post_subject': 'BBCode Suggestion', 'Author': 'simonhind', 'created_at': '2012-09-14T03:34:00', 'responses': 4, 'views_count': 76, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-14T14:13:00'}
# {'Post_subject': 'Blog entry and forum thread', 'Author': 'zascok', 'created_at': '2012-09-13T13:25:00', 'responses': 1, 'views_count': 39, 'last_post_by': 'Dominic', 'last_post_time': '2012-09-13T14:02:00'}
# {'Post_subject': 'Two suggestions', 'Author': 'waldvb', 'created_at': '2012-09-13T05:21:00', 'responses': 1, 'views_count': 31, 'last_post_by': 'Dominic', 'last_post_time': '2012-09-13T14:02:00'}
# {'Post_subject': 'Thread Preview display when hovering over title', 'Author': 'sadiq6210', 'created_at': '2012-09-12T23:23:00', 'responses': 0, 'views_count': 39, 'last_post_by': 'sadiq6210', 'last_post_time': '2012-09-12T23:23:00'}
# 16
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# {'Post_subject': 'Improve Thread Preview display when hovering over title', 'Author': 'sadiq6210', 'created_at': '2012-09-12T05:40:00', 'responses': 2, 'views_count': 75, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-12T09:19:00'}
# 17
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# 18
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# 19
# {'Post_subject': 'Voting for your favorite suggestions...', 'Author': 'Wayne Luke', 'created_at': '2013-08-06T21:51:00', 'responses': 7, 'views_count': 910, 'last_post_by': 'In Omnibus', 'last_post_time': '2016-08-28T07:05:00'}
# {'Post_subject': 'Before making a Suggestion...', 'Author': 'Wayne Luke', 'created_at': '2012-09-09T06:57:00', 'responses': 0, 'views_count': 946, 'last_post_by': 'Wayne Luke', 'last_post_time': '2012-09-09T06:57:00'}
# Completd
